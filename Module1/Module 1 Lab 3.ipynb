# %% [markdown]
# My recommendation is to use Progressive, it has the highest average from the customer ratings, in addition, the min rating was 6.7 which is still very high comparing to the min for both other...
