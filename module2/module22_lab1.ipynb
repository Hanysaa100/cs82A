# %% [markdown]
# I observe that the dataset contains 71 data,The chicken weights have an average of about 261 grams,the miunum chicken weights about 108 grams,the maximum chicken weights about 423 grams ,which reprsent a way diffrent betwen how to feed the chikecn ,the conclusion if we want to invist in chicken we should try several type of feeding to get the best results which is sunflower is this case only.
