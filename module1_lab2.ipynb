# %%
import pandas as pd
df = pd.read_csv('feed_summary_table.csv')
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 df = pd.read_csv('feed_summary_table.csv')
#       3 df
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# I recommend using sunflower feed as a good investment, which gives the best results all in all. Using sunflower gives the max weight compared to all the other feeds, in addition to the minimum weight and the average weight, beating the soybean with 14 chickens versus sunflower with only 12 chickens. However, the sunflower gives us the best return according to the data.
